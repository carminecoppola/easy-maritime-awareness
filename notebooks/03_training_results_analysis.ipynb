# %% [markdown]
# # Training Results Analysis
#
# Analyze YOLO training results and model performance.

# %% [markdown]
# ## 1. Setup

# %%
import os
import sys
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

sys.path.insert(0, str(Path.cwd() / 'src'))

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 6)

# %% [markdown]
# ## 2. Load Training Results

# %%
outputs_dir = Path('outputs')

if outputs_dir.exists():
    # Find training runs
    runs = list(outputs_dir.glob('**/results.csv'))
    
    if runs:
        print(f"Found {len(runs)} training run(s)")
        for run in runs:
            print(f"  - {run.parent.name}")
    else:
        print("No training results found yet")
else:
    print("No outputs directory yet")

# %% [markdown]
# ## 3. Plot Metrics (when available)

# %%
# Placeholder for metric visualization
print("Waiting for training results...")
print("Metrics will include:")
print("  - mAP50 and mAP50-95")
print("  - Precision and Recall")
print("  - Loss curves")
print("  - Class-wise performance")
